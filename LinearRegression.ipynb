# %% [markdown]
# <a href="https://colab.research.google.com/github/SlavaR07/Slavas/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df = pd.read_cvs('Expanded_data_with_more_features.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-17024e5aa6c8> in <cell line: 0>()
# ----> 1 df = pd.read_cvs('Expanded_data_with_more_features.csv')
#
# NameError: name 'pd' is not defined

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
df = pd.read_csv('Expanded_data_with_more_features.csv')

# %%
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0           none             married     regularly          yes         3.0
# 1            NaN             married     sometimes          yes         0.0
# 2           none              single     sometimes          yes         4.0
# 3           none             married         never           no         1.0
# 4           none             married     sometimes          yes         0.0
# ...          ...                 ...           ...          ...         ...
# 30636       none              single     sometimes           no         2.0
# 30637       none              single     regularly           no         1.0
# 30638  completed             married     sometimes           no         1.0
# 30639  completed             married     regularly           no         3.0
# 30640       none             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1                NaN         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3                NaN         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'EthnicGroup', 'ParentEduc', 'LunchType',
#        'TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild',
#        'NrSiblings', 'TransportMeans', 'WklyStudyHours', 'MathScore',
#        'ReadingScore', 'WritingScore'],
#       dtype='object')

# %%
lst = ['Unnamed: 0', 'Gender', 'EthnicGroup', 'ParentEduc', 'LunchType',
       'TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild',
       'NrSiblings', 'TransportMeans', 'WklyStudyHours', 'MathScore',
       'ReadingScore', 'WritingScore']
df = df[lst]

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df['EthnicGroup']
# Out:
# 0            NaN
# 1        group C
# 2        group B
# 3        group A
# 4        group C
#           ...
# 30636    group D
# 30637    group E
# 30638        NaN
# 30639    group D
# 30640    group B
# Name: EthnicGroup, Length: 30641, dtype: object

# %%
df.groupby('EthnicGroup').count()
# Out:
#              Unnamed: 0  Gender  ParentEduc  LunchType  TestPrep  \
# EthnicGroup
# group A            2219    2219        2078       2219      2081
# group B            5826    5826        5470       5826      5488
# group C            9212    9212        8652       9212      8652
# group D            7503    7503        7056       7503      7070
# group E            4041    4041        3814       4041      3804
#
#              ParentMaritalStatus  PracticeSport  IsFirstChild  NrSiblings  \
# EthnicGroup
# group A                     2121           2167          2168        2096
# group B                     5605           5704          5649        5546
# group C                     8858           9050          8929        8763
# group D                     7218           7343          7285        7106
# group E                     3892           3954          3918        3820
#
#              TransportMeans  WklyStudyHours  MathScore  ReadingScore  \
# EthnicGroup
# group A                1999            2146       2219          2219
# group B                5238            5642       5826          5826
# group C                8280            8933       9212          9212
# group D                6713            7270       7503          7503
# group E                3624            3924       4041          4041
#
#              WritingScore
# EthnicGroup
# group A              2219
# group B              5826
# group C              9212
# group D              7503
# group E              4041

# %%
df[['EthnicGroup']] = df[['EthnicGroup']].fillna('group C')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup               0
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df['ParentEduc'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school', nan],
#       dtype=object)

# %%
df.groupby('ParentEduc').count()
# Out:
#                     Unnamed: 0  Gender  EthnicGroup  LunchType  TestPrep  \
# ParentEduc
# associate's degree        5550    5550         5550       5550      5213
# bachelor's degree         3386    3386         3386       3386      3209
# high school               5687    5687         5687       5687      5341
# master's degree           2023    2023         2023       2023      1903
# some college              6633    6633         6633       6633      6216
# some high school          5517    5517         5517       5517      5192
#
#                     ParentMaritalStatus  PracticeSport  IsFirstChild  \
# ParentEduc
# associate's degree                 5351           5446          5380
# bachelor's degree                  3251           3320          3286
# high school                        5475           5568          5541
# master's degree                    1939           1985          1952
# some college                       6369           6488          6457
# some high school                   5295           5408          5336
#
#                     NrSiblings  TransportMeans  WklyStudyHours  MathScore  \
# ParentEduc
# associate's degree        5263            5026            5379       5550
# bachelor's degree         3213            3057            3269       3386
# high school               5387            5086            5503       5687
# master's degree           1927            1800            1967       2023
# some college              6313            5964            6442       6633
# some high school          5216            4930            5343       5517
#
#                     ReadingScore  WritingScore
# ParentEduc
# associate's degree          5550          5550
# bachelor's degree           3386          3386
# high school                 5687          5687
# master's degree             2023          2023
# some college                6633          6633
# some high school            5517          5517

# %%
df[['ParentEduc']] = df[['ParentEduc']].fillna('some college')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup               0
# ParentEduc                0
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df['TestPrep'].unique()
# Out:
# array(['none', nan, 'completed'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup               0
# ParentEduc                0
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df[['TestPrep']] = df[['TestPrep']].fillna('none')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup               0
# ParentEduc                0
# LunchType                 0
# TestPrep                  0
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df[['PracticeSport']] = df[['PracticeSport']].fillna('some college')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup               0
# ParentEduc                0
# LunchType                 0
# TestPrep                  0
# ParentMaritalStatus    1190
# PracticeSport             0
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df[['ReadingScore']] = df[['ReadingScore']].fillna('other')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup               0
# ParentEduc                0
# LunchType                 0
# TestPrep                  0
# ParentMaritalStatus    1190
# PracticeSport             0
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df[['WklyStudyHours']] = df[['WklyStudyHours']].fillna('some college')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup               0
# ParentEduc                0
# LunchType                 0
# TestPrep                  0
# ParentMaritalStatus    1190
# PracticeSport             0
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours            0
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df[['ParentMaritalStatus']] = df[['ParentMaritalStatus']].fillna('some college')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup               0
# ParentEduc                0
# LunchType                 0
# TestPrep                  0
# ParentMaritalStatus       0
# PracticeSport             0
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours            0
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df[['ParentMaritalStatus']] = df[['ParentMaritalStatus']].fillna('some college')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup               0
# ParentEduc                0
# LunchType                 0
# TestPrep                  0
# ParentMaritalStatus       0
# PracticeSport             0
# IsFirstChild              0
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours            0
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df[['NrSiblings']] = df[['NrSiblings']].fillna('some college')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup               0
# ParentEduc                0
# LunchType                 0
# TestPrep                  0
# ParentMaritalStatus       0
# PracticeSport             0
# IsFirstChild              0
# NrSiblings                0
# TransportMeans         3134
# WklyStudyHours            0
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df[['TransportMeans']] = df[['TransportMeans']].fillna('other')

# %%
df.isnull().sum()
# Out:
# Gender                 0
# EthnicGroup            0
# ParentEduc             0
# LunchType              0
# TestPrep               0
# ParentMaritalStatus    0
# PracticeSport          0
# IsFirstChild           0
# NrSiblings             0
# TransportMeans         0
# WklyStudyHours         0
# MathScore              0
# ReadingScore           0
# WritingScore           0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# %%
df['Gender'] = label_encoder.fit_transform(df['Gender'])

# %%
df
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0           0     group C   bachelor's degree      standard       none
# 1           0     group C        some college      standard       none
# 2           0     group B     master's degree      standard       none
# 3           1     group A  associate's degree  free/reduced       none
# 4           1     group C        some college      standard       none
# ...       ...         ...                 ...           ...        ...
# 30636       0     group D         high school      standard       none
# 30637       1     group E         high school      standard       none
# 30638       0     group C         high school  free/reduced  completed
# 30639       0     group D  associate's degree      standard  completed
# 30640       1     group B        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild NrSiblings  \
# 0                 married     regularly          yes        3.0
# 1                 married     sometimes          yes        0.0
# 2                  single     sometimes          yes        4.0
# 3                 married         never           no        1.0
# 4                 married     sometimes          yes        0.0
# ...                   ...           ...          ...        ...
# 30636              single     sometimes           no        2.0
# 30637              single     regularly           no        1.0
# 30638             married     sometimes           no        1.0
# 30639             married     regularly           no        3.0
# 30640             married         never           no        1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1              other         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3              other         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 14 columns]

# %%
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0           0     group C   bachelor's degree      standard       none
# 1           0     group C        some college      standard       none
# 2           0     group B     master's degree      standard       none
# 3           1     group A  associate's degree  free/reduced       none
# 4           1     group C        some college      standard       none
# ...       ...         ...                 ...           ...        ...
# 30636       0     group D         high school      standard       none
# 30637       1     group E         high school      standard       none
# 30638       0     group C         high school  free/reduced  completed
# 30639       0     group D  associate's degree      standard  completed
# 30640       1     group B        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild NrSiblings  \
# 0                 married     regularly          yes        3.0
# 1                 married     sometimes          yes        0.0
# 2                  single     sometimes          yes        4.0
# 3                 married         never           no        1.0
# 4                 married     sometimes          yes        0.0
# ...                   ...           ...          ...        ...
# 30636              single     sometimes           no        2.0
# 30637              single     regularly           no        1.0
# 30638             married     sometimes           no        1.0
# 30639             married     regularly           no        3.0
# 30640             married         never           no        1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1              other         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3              other         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 14 columns]

# %%
df['EthnicGroup'] = label_encoder.fit_transform(df['EthnicGroup'])
df
# Out:
#        Gender  EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0           0            2   bachelor's degree      standard       none
# 1           0            2        some college      standard       none
# 2           0            1     master's degree      standard       none
# 3           1            0  associate's degree  free/reduced       none
# 4           1            2        some college      standard       none
# ...       ...          ...                 ...           ...        ...
# 30636       0            3         high school      standard       none
# 30637       1            4         high school      standard       none
# 30638       0            2         high school  free/reduced  completed
# 30639       0            3  associate's degree      standard  completed
# 30640       1            1        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild NrSiblings  \
# 0                 married     regularly          yes        3.0
# 1                 married     sometimes          yes        0.0
# 2                  single     sometimes          yes        4.0
# 3                 married         never           no        1.0
# 4                 married     sometimes          yes        0.0
# ...                   ...           ...          ...        ...
# 30636              single     sometimes           no        2.0
# 30637              single     regularly           no        1.0
# 30638             married     sometimes           no        1.0
# 30639             married     regularly           no        3.0
# 30640             married         never           no        1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1              other         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3              other         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 14 columns]

# %%
df['ParentEduc'] = label_encoder.fit_transform(df['ParentEduc'])
df
# Out:
#        Gender  EthnicGroup  ParentEduc     LunchType   TestPrep  \
# 0           0            2           1      standard       none
# 1           0            2           4      standard       none
# 2           0            1           3      standard       none
# 3           1            0           0  free/reduced       none
# 4           1            2           4      standard       none
# ...       ...          ...         ...           ...        ...
# 30636       0            3           2      standard       none
# 30637       1            4           2      standard       none
# 30638       0            2           2  free/reduced  completed
# 30639       0            3           0      standard  completed
# 30640       1            1           4      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild NrSiblings  \
# 0                 married     regularly          yes        3.0
# 1                 married     sometimes          yes        0.0
# 2                  single     sometimes          yes        4.0
# 3                 married         never           no        1.0
# 4                 married     sometimes          yes        0.0
# ...                   ...           ...          ...        ...
# 30636              single     sometimes           no        2.0
# 30637              single     regularly           no        1.0
# 30638             married     sometimes           no        1.0
# 30639             married     regularly           no        3.0
# 30640             married         never           no        1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1              other         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3              other         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 14 columns]

# %%
df['LunchType'] = label_encoder.fit_transform(df['LunchType'])
df
# Out:
#        Gender  EthnicGroup  ParentEduc  LunchType   TestPrep  \
# 0           0            2           1          1       none
# 1           0            2           4          1       none
# 2           0            1           3          1       none
# 3           1            0           0          0       none
# 4           1            2           4          1       none
# ...       ...          ...         ...        ...        ...
# 30636       0            3           2          1       none
# 30637       1            4           2          1       none
# 30638       0            2           2          0  completed
# 30639       0            3           0          1  completed
# 30640       1            1           4          1       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild NrSiblings  \
# 0                 married     regularly          yes        3.0
# 1                 married     sometimes          yes        0.0
# 2                  single     sometimes          yes        4.0
# 3                 married         never           no        1.0
# 4                 married     sometimes          yes        0.0
# ...                   ...           ...          ...        ...
# 30636              single     sometimes           no        2.0
# 30637              single     regularly           no        1.0
# 30638             married     sometimes           no        1.0
# 30639             married     regularly           no        3.0
# 30640             married         never           no        1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1              other         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3              other         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 14 columns]

# %%
df['TestPrep'] = label_encoder.fit_transform(df['TestPrep'])
df
# Out:
#        Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  \
# 0           0            2           1          1         1
# 1           0            2           4          1         1
# 2           0            1           3          1         1
# 3           1            0           0          0         1
# 4           1            2           4          1         1
# ...       ...          ...         ...        ...       ...
# 30636       0            3           2          1         1
# 30637       1            4           2          1         1
# 30638       0            2           2          0         0
# 30639       0            3           0          1         0
# 30640       1            1           4          1         1
#
#       ParentMaritalStatus PracticeSport IsFirstChild NrSiblings  \
# 0                 married     regularly          yes        3.0
# 1                 married     sometimes          yes        0.0
# 2                  single     sometimes          yes        4.0
# 3                 married         never           no        1.0
# 4                 married     sometimes          yes        0.0
# ...                   ...           ...          ...        ...
# 30636              single     sometimes           no        2.0
# 30637              single     regularly           no        1.0
# 30638             married     sometimes           no        1.0
# 30639             married     regularly           no        3.0
# 30640             married         never           no        1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1              other         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3              other         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 14 columns]

# %%
df['ParentMaritalStatus'] = label_encoder.fit_transform(df['ParentMaritalStatus'])
df
# Out:
#        Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  \
# 0           0            2           1          1         1
# 1           0            2           4          1         1
# 2           0            1           3          1         1
# 3           1            0           0          0         1
# 4           1            2           4          1         1
# ...       ...          ...         ...        ...       ...
# 30636       0            3           2          1         1
# 30637       1            4           2          1         1
# 30638       0            2           2          0         0
# 30639       0            3           0          1         0
# 30640       1            1           4          1         1
#
#        ParentMaritalStatus PracticeSport IsFirstChild NrSiblings  \
# 0                        1     regularly          yes        3.0
# 1                        1     sometimes          yes        0.0
# 2                        2     sometimes          yes        4.0
# 3                        1         never           no        1.0
# 4                        1     sometimes          yes        0.0
# ...                    ...           ...          ...        ...
# 30636                    2     sometimes           no        2.0
# 30637                    2     regularly           no        1.0
# 30638                    1     sometimes           no        1.0
# 30639                    1     regularly           no        3.0
# 30640                    1         never           no        1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1              other         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3              other         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 14 columns]

# %%
df['PracticeSport'] = label_encoder.fit_transform(df['PracticeSport'])
df
# Out:
#        Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  \
# 0           0            2           1          1         1
# 1           0            2           4          1         1
# 2           0            1           3          1         1
# 3           1            0           0          0         1
# 4           1            2           4          1         1
# ...       ...          ...         ...        ...       ...
# 30636       0            3           2          1         1
# 30637       1            4           2          1         1
# 30638       0            2           2          0         0
# 30639       0            3           0          1         0
# 30640       1            1           4          1         1
#
#        ParentMaritalStatus  PracticeSport IsFirstChild NrSiblings  \
# 0                        1              1          yes        3.0
# 1                        1              3          yes        0.0
# 2                        2              3          yes        4.0
# 3                        1              0           no        1.0
# 4                        1              3          yes        0.0
# ...                    ...            ...          ...        ...
# 30636                    2              3           no        2.0
# 30637                    2              1           no        1.0
# 30638                    1              3           no        1.0
# 30639                    1              1           no        3.0
# 30640                    1              0           no        1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1              other         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3              other         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 14 columns]

# %%
df['IsFirstChild'] = label_encoder.fit_transform(df['IsFirstChild	'])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'IsFirstChild\t'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-db92308ab45f> in <cell line: 0>()
# ----> 1 df['IsFirstChild'] = label_encoder.fit_transform(df['IsFirstChild       '])
#       2 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'IsFirstChild\t'
